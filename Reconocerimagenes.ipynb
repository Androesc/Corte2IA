# %%
# --------------------------
# Punto 1: Preparación del entorno y datos
# --------------------------
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Cargar y preparar los datos
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

train_images = train_images.astype('float32') / 255.0
test_images = test_images.astype('float32') / 255.0

train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

class_names = ['Avión', 'Automóvil', 'Pájaro', 'Gato', 'Ciervo',
               'Perro', 'Rana', 'Caballo', 'Barco', 'Camión']

def visualizar_imagenes(images, labels, class_names):
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i])
        plt.title(class_names[np.argmax(labels[i])])
    plt.tight_layout()
    plt.show()

visualizar_imagenes(train_images, train_labels, class_names)

# --------------------------
# Punto 2: Construcción de una CNN básica
# --------------------------
def crear_modelo_cnn():
    modelo = models.Sequential()
    modelo.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    modelo.add(layers.MaxPooling2D((2, 2)))
    modelo.add(layers.Conv2D(64, (3, 3), activation='relu'))
    modelo.add(layers.MaxPooling2D((2, 2)))
    modelo.add(layers.Conv2D(64, (3, 3), activation='relu'))
    modelo.add(layers.Flatten())
    modelo.add(layers.Dense(64, activation='relu'))
    modelo.add(layers.Dense(10, activation='softmax'))
    modelo.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])
    return modelo

modelo_cnn = crear_modelo_cnn()
modelo_cnn.summary()

# --------------------------
# Punto 3: Entrenamiento del modelo
# --------------------------
def entrenar_modelo(modelo, train_images, train_labels, test_images, test_labels, epochs=10):
    historial = modelo.fit(
        train_images,
        train_labels,
        epochs=epochs,
        validation_data=(test_images, test_labels)
    )
    resultados = modelo.evaluate(test_images, test_labels)
    print(f"Precisión en datos de prueba: {resultados[1]:.4f}")
    return historial

def visualizar_historial(historial):
    acc = historial.history['accuracy']
    val_acc = historial.history['val_accuracy']
    loss = historial.history['loss']
    val_loss = historial.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Precisión entrenamiento')
    plt.plot(epochs_range, val_acc, label='Precisión validación')
    plt.legend(loc='lower right')
    plt.title('Precisión durante el entrenamiento')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Pérdida entrenamiento')
    plt.plot(epochs_range, val_loss, label='Pérdida validación')
    plt.legend(loc='upper right')
    plt.title('Pérdida durante el entrenamiento')
    plt.tight_layout()
    plt.show()

historial = entrenar_modelo(modelo_cnn, train_images, train_labels, test_images, test_labels)
visualizar_historial(historial)

# --------------------------
# Punto 4: Predicción y evaluación visual
# --------------------------
def predecir_y_visualizar(modelo, images, labels, class_names, num_imagenes=5):
    indices = np.random.choice(len(images), num_imagenes, replace=False)
    predicciones = modelo.predict(images[indices])
    clases_predichas = np.argmax(predicciones, axis=1)
    clases_reales = np.argmax(labels[indices], axis=1)

    plt.figure(figsize=(12, 3 * num_imagenes))
    for i, idx in enumerate(indices):
        plt.subplot(num_imagenes, 1, i + 1)
        plt.imshow(images[idx])
        color = 'green' if clases_predichas[i] == clases_reales[i] else 'red'
        plt.title(f"Real: {class_names[clases_reales[i]]} | Predicción: {class_names[clases_predichas[i]]}", color=color)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

def mostrar_matriz_confusion(modelo, images, labels, class_names):
    predicciones = modelo.predict(images)
    clases_predichas = np.argmax(predicciones, axis=1)
    clases_reales = np.argmax(labels, axis=1)
    matriz = confusion_matrix(clases_reales, clases_predichas)
    plt.figure(figsize=(10, 8))
    sns.heatmap(matriz, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Etiqueta Predicha')
    plt.ylabel('Etiqueta Real')
    plt.title('Matriz de Confusión')
    plt.show()

predecir_y_visualizar(modelo_cnn, test_images, test_labels, class_names)
mostrar_matriz_confusion(modelo_cnn, test_images, test_labels, class_names)

# --------------------------
# Punto 5: Mejoras y experimentación
# --------------------------
def crear_modelo_mejorado():
    modelo = models.Sequential()
    modelo.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
    modelo.add(BatchNormalization())
    modelo.add(layers.MaxPooling2D((2, 2)))
    modelo.add(Dropout(0.25))
    modelo.add(layers.Conv2D(64, (3, 3), activation='relu'))
    modelo.add(BatchNormalization())
    modelo.add(layers.MaxPooling2D((2, 2)))
    modelo.add(Dropout(0.25))
    modelo.add(layers.Conv2D(128, (3, 3), activation='relu'))
    modelo.add(BatchNormalization())
    modelo.add(Dropout(0.3))
    modelo.add(layers.Flatten())
    modelo.add(layers.Dense(256, activation='relu'))
    modelo.add(Dropout(0.5))
    modelo.add(layers.Dense(10, activation='softmax'))

    optimizador = tf.keras.optimizers.Adam(learning_rate=0.0005)
    modelo.compile(optimizer=optimizador,
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])
    return modelo

def aplicar_data_augmentation():
    datagen = ImageDataGenerator(
        rotation_range=15,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=True,
        zoom_range=0.1
    )
    datagen.fit(train_images)
    return datagen

modelo_mejorado = crear_modelo_mejorado()
modelo_mejorado.summary()

datagen = aplicar_data_augmentation()

# Entrenamiento con data augmentation
hist_mejorado = modelo_mejorado.fit(
    datagen.flow(train_images, train_labels, batch_size=64),
    epochs=15,
    validation_data=(test_images, test_labels)
)

visualizar_historial(hist_mejorado)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 4, 4, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        65,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 122,570 (478.79 KB)
#  Trainable params: 122,570 (478.79 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 51ms/step - accuracy: 0.3583 - loss: 1.7344 - val_accuracy: 0.5467 - val_loss: 1.2543
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 75s 48ms/step - accuracy: 0.5753 - loss: 1.1929 - val_accuracy: 0.6185 - val_loss: 1.0695
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 73s 47ms/step - accuracy: 0.6366 - loss: 1.0277 - val_accuracy: 0.6426 - val_loss: 1.0143
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 49ms/step - accuracy: 0.6801 - loss: 0.9184 - val_accuracy: 0.6700 - val_loss: 0.9403
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 47ms/step - accuracy: 0.7020 - loss: 0.8496 - val_accuracy: 0.6771 - val_loss: 0.9233
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 75s 48ms/step - accuracy: 0.7178 - loss: 0.7905 - val_accuracy: 0.6723 - val_loss: 0.9535
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 86s 51ms/step - accuracy: 0.7425 - loss: 0.7372 - val_accuracy: 0.6941 - val_loss: 0.8877
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 77s 48ms/step - accuracy: 0.7589 - loss: 0.6839 - val_accuracy: 0.7004 - val_loss: 0.8983
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 74s 47ms/step - accuracy: 0.7757 - loss: 0.6383 - val_accuracy: 0.7034 - val_loss: 0.8758
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 85s 49ms/step - accuracy: 0.7878 - loss: 0.6016 - val_accuracy: 0.7035 - val_loss: 0.8847
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.7059 - loss: 0.8715
# Precisión en datos de prueba: 0.7035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 621,258 (2.37 MB)
#  Trainable params: 620,810 (2.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/15
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 197ms/step - accuracy: 0.2810 - loss: 2.4541 - val_accuracy: 0.5016 - val_loss: 1.3890
# Epoch 2/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 162s 207ms/step - accuracy: 0.4445 - loss: 1.5528 - val_accuracy: 0.4980 - val_loss: 1.5129
# Epoch 3/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 196s 200ms/step - accuracy: 0.4990 - loss: 1.3910 - val_accuracy: 0.5556 - val_loss: 1.3157
# Epoch 4/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 150s 192ms/step - accuracy: 0.5356 - loss: 1.2990 - val_accuracy: 0.4727 - val_loss: 1.7640
# Epoch 5/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 206s 198ms/step - accuracy: 0.5539 - loss: 1.2398 - val_accuracy: 0.6211 - val_loss: 1.0814
# Epoch 6/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 160s 204ms/step - accuracy: 0.5797 - loss: 1.1866 - val_accuracy: 0.6541 - val_loss: 0.9750
# Epoch 7/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 203ms/step - accuracy: 0.5972 - loss: 1.1485 - val_accuracy: 0.5597 - val_loss: 1.4371
# Epoch 8/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 197s 196ms/step - accuracy: 0.6077 - loss: 1.1062 - val_accuracy: 0.6490 - val_loss: 1.0075
# Epoch 9/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 203s 198ms/step - accuracy: 0.6201 - loss: 1.0808 - val_accuracy: 0.6104 - val_loss: 1.1865
# Epoch 10/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 201ms/step - accuracy: 0.6306 - loss: 1.0467 - val_accuracy: 0.7086 - val_loss: 0.8339
# Epoch 11/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 151s 193ms/step - accuracy: 0.6386 - loss: 1.0258 - val_accuracy: 0.6498 - val_loss: 1.0757
# Epoch 12/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 159s 203ms/step - accuracy: 0.6438 - loss: 1.0148 - val_accuracy: 0.7038 - val_loss: 0.8437
# Epoch 13/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 156s 199ms/step - accuracy: 0.6529 - loss: 0.9879 - val_accuracy: 0.6562 - val_loss: 0.9952
# Epoch 14/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 157s 200ms/step - accuracy: 0.6617 - loss: 0.9712 - val_accuracy: 0.7210 - val_loss: 0.7960
# Epoch 15/15
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 151s 193ms/step - accuracy: 0.6642 - loss: 0.9614 - val_accuracy: 0.6925 - val_loss: 0.8935
